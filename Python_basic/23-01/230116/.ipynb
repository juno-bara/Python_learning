# %%
91962600000000*10.09
# Out:
# 927902634000000.0

# %%
927902634000000.0/8.6
# Out:
# 107895655116279.08

# %%
import pandas as pd

# %%
df = pd.read_csv("../csv/chipotle.csv")
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.dropna()
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...

# %%
df["item_price"] = df["item_price"].str.replace("$","")
df
# Out:
# C:\Users\이주노\AppData\Local\Temp\ipykernel_35724\3769706161.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["item_price"] = df["item_price"].str.replace("$","")
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# ...

# %%
df["item_price"] = df["item_price"].astype(float)

# %%
df[df["item_price"]== 11.75]
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 39          19         1  Barbacoa Bowl
# 43          20         1  Steak Burrito
# 58          27         1  Barbacoa Bowl
# 90          40         1     Steak Bowl
# ...        ...       ...            ...
# 4594      1825         1  Barbacoa Bowl
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description  item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 39    [Roasted Chili Corn Salsa, [Fajita Vegetables,...       11.75
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...       11.75
# 58    [Roasted Chili Corn Salsa, [Fajita Vegetables,...       11.75
# 90    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       11.75
# ...                                                 ...         ...
# ...

# %%
df["order_id"].value_counts(ascending = False)
# Out:
# 926     23
# 1483    14
# 205     12
# 759     11
# 1786    11
#         ..
# 768      1
# 341      1
# 1048     1
# 94       1
# 1199     1
# Name: order_id, Length: 1834, dtype: int64

# %%
df[df["order_id"] == 1483].reset_index()["item_price"].sum()
# Out:
# 139.0

# %%
df_926 = df[df["order_id"] == 926]

# %%
df_926
# Out:
#       order_id  quantity           item_name  \
# 2304       926         1       Steak Burrito
# 2305       926         1        Chicken Bowl
# 2306       926         1        Chicken Bowl
# 2307       926         1        Chicken Bowl
# 2308       926         1          Steak Bowl
# 2309       926         1        Chicken Bowl
# 2310       926         1       Steak Burrito
# 2311       926         1     Chicken Burrito
# 2312       926         1        Chicken Bowl
# 2313       926         1        Chicken Bowl
# 2314       926         1  Chicken Salad Bowl
# 2315       926         1          Steak Bowl
# 2316       926         1     Chicken Burrito
# 2317       926         1          Steak Bowl
# 2318       926         1        Chicken Bowl
# 2319       926         1          Steak Bowl
# 2320       926         1     Chicken Burrito
# 2321       926         1        Chicken Bowl
# 2322       926         1        Chicken Bowl
# 2323       926         1    Barbacoa Burrito
# ...

# %%
len(df_926)
# Out:
# 23

# %%
df_926["choice_description"].unique()
# Out:
# array(['[Fresh Tomato Salsa, [Rice, Sour Cream, Lettuce]]',
#        '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]',
#        '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream]]',
#        '[Fresh Tomato Salsa, [Rice, Black Beans, Lettuce]]',
#        '[Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]',
#        '[Roasted Chili Corn Salsa, [Rice, Cheese, Sour Cream, Lettuce]]',
#        '[Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Lettuce]]',
#        '[Fresh Tomato Salsa, [Rice, Lettuce]]',
#        '[Fresh Tomato Salsa, [Rice, Cheese, Sour Cream, Lettuce]]',
#        '[Roasted Chili Corn Salsa, [Rice, Sour Cream]]',
#        '[Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]',
#        '[Roasted Chili Corn Salsa, [Rice, Black Beans, Sour Cream]]',
#        '[Fresh Tomato Salsa, [Rice, Cheese]]',
#        '[Fresh Tomato Salsa, [Rice, Cheese, Lettuce]]',
# ...

# %%
df_926[df_926.duplicated(["order_id", "item_name", "choice_description", "item_price"])]
# Out:
#       order_id  quantity     item_name  \
# 2307       926         1  Chicken Bowl
# 2318       926         1  Chicken Bowl
#
#                                      choice_description  item_price
# 2307  [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# 2318  [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75

# %%
df_926.drop_duplicates()
# Out:
#       order_id  quantity           item_name  \
# 2304       926         1       Steak Burrito
# 2305       926         1        Chicken Bowl
# 2306       926         1        Chicken Bowl
# 2308       926         1          Steak Bowl
# 2309       926         1        Chicken Bowl
# 2310       926         1       Steak Burrito
# 2311       926         1     Chicken Burrito
# 2312       926         1        Chicken Bowl
# 2313       926         1        Chicken Bowl
# 2314       926         1  Chicken Salad Bowl
# 2315       926         1          Steak Bowl
# 2316       926         1     Chicken Burrito
# 2317       926         1          Steak Bowl
# 2319       926         1          Steak Bowl
# 2320       926         1     Chicken Burrito
# 2321       926         1        Chicken Bowl
# 2322       926         1        Chicken Bowl
# 2323       926         1    Barbacoa Burrito
# 2324       926         1     Chicken Burrito
# 2325       926         1          Steak Bowl
# ...

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %%
df.describe()
# Out:
#          order_id     quantity   item_price
# count  3376.00000  3376.000000  3376.000000
# mean    920.33205     1.063389     9.011321
# std     528.96664     0.283070     3.791337
# min       1.00000     1.000000     1.090000
# 25%     466.75000     1.000000     8.690000
# 50%     922.00000     1.000000     8.990000
# 75%    1382.25000     1.000000    11.250000
# max    1834.00000     4.000000    35.250000

# %%
df.fillna(df["item_price"].mean())
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %%
import FinanceDataReader as fdr

# %%
sm = fdr.DataReader("005930", "20220101", "20221231")
sm
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-01-03  79400  79800  78200  78600  13502112  0.003831
# 2022-01-04  78800  79200  78300  78700  12427416  0.001272
# 2022-01-05  78800  79000  76400  77400  25470640 -0.016518
# 2022-01-06  76700  77600  76600  76900  12931954 -0.006460
# 2022-01-07  78100  78400  77400  78300  15163757  0.018205
# ...           ...    ...    ...    ...       ...       ...
# 2022-12-23  58200  58400  57700  58100   9829407 -0.016920
# 2022-12-26  58000  58100  57700  57900   6756411 -0.003442
# 2022-12-27  58000  58400  57900  58100  10667027  0.003454
# 2022-12-28  57600  57600  56400  56600  14665410 -0.025818
# 2022-12-29  56000  56200  55300  55300  11295935 -0.022968
#
# [246 rows x 6 columns]

# %%
sm.describe()
# 연수익률 = 256 * mean (이동편균선 20일 >> 월 이동평균선, 이동편균선 60 >>> 3개월 이동평균선)
# 위험도 = 루트 std
# Out:
#                Open          High           Low         Close        Volume  \
# count    246.000000    246.000000    246.000000    246.000000  2.460000e+02
# mean   63996.341463  64493.495935  63458.943089  63935.365854  1.448451e+07
# std     6709.763434   6618.912172   6623.950152   6625.615818  4.890389e+06
# min    52300.000000  53600.000000  51800.000000  52600.000000  5.767902e+06
# 25%    58700.000000  59225.000000  58200.000000  58800.000000  1.103933e+07
# 50%    61650.000000  62000.000000  61050.000000  61700.000000  1.362839e+07
# 75%    68800.000000  69225.000000  68575.000000  69000.000000  1.693226e+07
# max    79500.000000  79800.000000  78600.000000  78900.000000  3.794336e+07
#
#            Change
# count  246.000000
# mean    -0.001311
# std      0.014336
# min     -0.036975
# 25%     -0.010952
# 50%     -0.001744
# 75%      0.006305
# max      0.044964

# %%
import seaborn as sns

# %%
# 회귀분석 가정 >>> 1 정규성

# %%
sns.histplot(sm["Change"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 sns.histplot(sm["Change"])
#
# NameError: name 'sm' is not defined

# %%
sns.histplot(sm["Change"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 sns.histplot(sm["Change"])
#
# NameError: name 'sns' is not defined

# %%
stats.shapiro(sm["Change"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 stats.shapiro(sm["Change"])
#
# NameError: name 'stats' is not defined

# %%
from scipy.stats import  norm
