# %%
 	#웹 페이지 열기
import time
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
 
import requests
import csv
import urllib.request
import urllib.parse
import re
from bs4 import BeautifulSoup

# %%
	#구글 인증
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.5563.65 Safari/537.36"}

list=[]
 
url = "https://map.kakao.com/"
#현재파일에 있는 크롬 드라이버를 가져와서 열기
options = webdriver.ChromeOptions() # 크롬 브라우저 옵션
# options.add_argument('headless') # 브라우저 안 띄우기
options.add_argument('lang=ko_KR') #  KR 언어
chromedriver_path = "chromedriver" # 크롬 드라이버 위치
driver = webdriver.Chrome(os.path.join(os.getcwd(), chromedriver_path), options=options)  # chromedriver 열기
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4424\3417293414.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(os.path.join(os.getcwd(), chromedriver_path), options=options)  # chromedriver 열기

# %%
from selenium.webdriver.common.by import By
# 1. 카카오 지도로 이동
driver.get(url)
 
searchloc = input("찾고싶은 음식종류")
filename = input("파일이름: 영어로치기")
print([searchloc , str(filename)])

#2. 서울시 음식점 입력 후 찾기 버튼 클릭 xpath활용
search_area = driver.find_element(By.XPATH , '//*[@id="search.keyword.query"]')
# search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]') # 검색 창
search_area.send_keys(searchloc)  # 검색어 입력

enter_button = driver.find_element(By.XPATH , '//*[@id="search.keyword.submit"]')
enter_button.send_keys(Keys.ENTER)

time.sleep(2)
#3 장소 버튼 클릭
area_button = driver.find_element(By.XPATH , '//*[@id="info.main.options"]/li[2]/a')
area_button.click()
# driver.find_element_by_xpath('//*[@id="info.main.options"]/li[2]/a').send_keys(Keys.ENTER)
# Out:
# 찾고싶은 음식종류서울 한식집
# 파일이름: 영어로치기seoul_traditional_retaurant
# ['서울 한식집', 'seoul_traditional_retaurant']

# %%
def storeNamePrint():
    
    time.sleep(0.2)
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    cafe_lists = soup.select('.placelist > .PlaceItem')
#     print(cafe_lists)
    count =1
    for cafe in cafe_lists:
        
        temp=[]
        cafe_name = cafe.select('.head_item > .tit_name > .link_name')[0].text  # cafeName 
        food_score = cafe.select('.rating > .score > .num')[0].text
        review = cafe.select('.rating > .review')[0].text
        link = cafe.select('.contact > .moreview' )[0]['href']
        addr = cafe.select('.addr')[0].text
        
        
        #"리뷰" 문자열 제거 후 숫자만 반환
        review= review[3:len(review)]
        
        #숫자만 반환된 문자를 쉼표를 
        review = int(re.sub(",","",review))
        
        print(cafe_name, food_score, review, link, addr)
     
        temp.append(cafe_name)
        temp.append(food_score)
        temp.append(review)
        temp.append(link)
        temp.append(addr)
        
        list.append(temp)
    print(temp)
    f=open(filename+'.csv',"w",encoding="utf-8-sig",newline="")
    writercsv=csv.writer(f)
    header=['Name','Score','Review','Link','Addr']
    writercsv.writerow(header)
 
    for i in list:
        writercsv.writerow(i)

# %%
storeNamePrint()
# Out:
# 서일순대국전문 구로점 4.1 35 https://place.map.kakao.com/16475939
# 서울 구로구 구로중앙로 6 1층
# (지번) 구로동 142-77
#
# 햇빛촌순대국  20 https://place.map.kakao.com/19009929
# 서울 금천구 벚꽃로38길 32-39 1층
# (지번) 가산동 83-13
#
# 영미네순대국 5.0 0 https://place.map.kakao.com/1187642392
# 서울 구로구 디지털로27길 100
# (지번) 구로동 797-65
#
# 현정이네토종순대국 4.6 6 https://place.map.kakao.com/18779333
# 서울 구로구 구로동로26길 121
# (지번) 구로동 313-11
#
# 참조은순대국전문점 구로직영점 3.7 20 https://place.map.kakao.com/26092443
# 서울 구로구 구로중앙로 47
# (지번) 구로동 87-1
#
# 삼거리먼지막순대국 4.1 142 https://place.map.kakao.com/9125675
# 서울 영등포구 시흥대로185길 11
# (지번) 대림동 963-9
#
# 진순대국 4.3 3 https://place.map.kakao.com/1954625855
# 서울 구로구 디지털로 288
# (지번) 구로동 212-8
#
# 우리순대국 4.0 1 https://place.map.kakao.com/652738067
# 서울 구로구 우마2길 75 1층
# (지번) 가리봉동 115-4
#
# 가산순대국 2.8 3 https://place.map.kakao.com/15621659
# 서울 금천구 가산로 147-7
# (지번) 가산동 143-11
#
# 대두족발 3.8 153 https://place.map.kakao.com/1157104232
# 서울 구로구 디지털로32길 97-6 1층
# (지번) 구로동 1125-10
#
# ...

# %%
#서울시 전 음식점 받아오기 위해 
 
page =1
page2=0
 
#1페이지부터 34페이지까지 출력
for i in range(0,34):  
 
    #페이지 넘어가며 출력 
    try:
        page2 +=1 
        print("**",page,"**")
        driver.find_element(By.XPATH ,f'//*[@id="info.search.page.no{page2}"]').send_keys(Keys.ENTER)
        storeNamePrint()
 
        if (page2)%5==0:
            driver.find_element(By.XPATH ,'//*[@id="info.search.page.next"]').send_keys(Keys.ENTER)
            page2=0
 
        page+=1
    except:
        break
print("**크롤링완료**")
# Out:
# ** 1 **
# 진미평양냉면 3.6 899 https://place.map.kakao.com/27584230
# 서울 강남구 학동로 305-3 정각빌딩 1층
# (지번) 논현동 115-10
#
# 금돼지식당 3.8 1148 https://place.map.kakao.com/1065693087
# 서울 중구 다산로 149 1~3층
# (지번) 신당동 370-69
#
# 중앙해장 3.9 949 https://place.map.kakao.com/27531028
# 서울 강남구 영동대로86길 17 육인빌딩 1층
# (지번) 대치동 996-16
#
# 청진옥 2.9 258 https://place.map.kakao.com/27540102
# 서울 종로구 종로3길 32
# (지번) 청진동 183-1
#
# 진옥화할매원조닭한마리 본점 3.4 710 https://place.map.kakao.com/10785496
# 서울 종로구 종로40가길 18
# (지번) 종로5가 265-22
#
# 청와옥 본점 3.2 774 https://place.map.kakao.com/1677426767
# 서울 송파구 위례성대로 48 반도빌딩 1층 102호
# (지번) 방이동 177-3
#
# 몽탄 3.3 1951 https://place.map.kakao.com/220597413
# 서울 용산구 백범로99길 50 1,2층
# (지번) 한강로1가 252-1
#
# 삼청동수제비 2.9 959 https://place.map.kakao.com/13559837
# 서울 종로구 삼청로 101-1
# (지번) 삼청동 102-2
#
# 삼육가 사당역1호점 4.2 154 https://place.map.kakao.com/211389635
# 서울 서초구 방배천로 10 1층
# (지번) 방배동 450-16
#
# 우래옥 본점 4.0 897 https://place.map.kakao.com/8025375
# 서울 중구 창경궁로 62-29
# (지번) 주교동 118-1
#
# ...

# %%
import pandas as pd 

df = pd.read_csv('seoul_traditional_retaurant.csv', encoding='utf-8')
df['Score'] = df['Score'].fillna(0)
df['Review'] = df['Review'].fillna(0)

# %%
df
# Out:
#                 Name  Score  Review                                    Link  \
# 0        서일순대국전문 구로점    4.1      35    https://place.map.kakao.com/16475939
# 1             햇빛촌순대국    0.0      20    https://place.map.kakao.com/19009929
# 2             영미네순대국    5.0       0  https://place.map.kakao.com/1187642392
# 3          현정이네토종순대국    4.6       6    https://place.map.kakao.com/18779333
# 4    참조은순대국전문점 구로직영점    3.7      20    https://place.map.kakao.com/26092443
# ..               ...    ...     ...                                     ...
# 525      명인등심 압구정직영점    4.3      62    https://place.map.kakao.com/21401237
# 526        샘밭막국수 서초점    3.2      35   https://place.map.kakao.com/130561410
# 527              옥탑방    4.4     375  https://place.map.kakao.com/1817798476
# 528           고깃집왕고을    4.2     118  https://place.map.kakao.com/1294029566
# 529              채화정    3.9      76     https://place.map.kakao.com/8539855
#
#                                                   Addr
# ...

# %%
df.isnull().sum()
df.shape
# Out:
# (530, 5)

# %%
df = df.drop(df[df['Score'] <= 3.0].index)

# %%
df.shape
# Out:
# (425, 5)

# %%
df = df.drop(df[df['Review'] <=10].index)

# %%
df.shape
# Out:
# (415, 5)

# %%
df = df.drop(df[df['Review'] <=300].index)

# %%
df.shape
# Out:
# (87, 5)

# %%
df.to_csv('best_restaurant.csv', encoding='utf-8-sig')

# %%
#크롤링해온 음식점 위도 경도값 저장하기
#서울
 
import googlemaps
import pandas as pd
df_list=pd.read_csv('best_restaurant.csv',encoding='utf-8')
 
 
 
# 구글맵 키
gmaps_key = "AIzaSyCje4m9rbpl6Lcd-nROu2iIZiIxq2XOiYc"
gmaps = googlemaps.Client(key = gmaps_key)
 
# 빈 리스트 생성(위도, 경도)
place_lat = []
place_lng = []
 
# 위경도 최대최소값
#우리나라 위도 경도값
max_lat = 38.0
min_lat = 33.0
max_lng = 132.0
min_lng = 126.0
 
 
#place
#df_list는 csv배열로 변경 해주기
 
for place in df_list["Addr"]:
    tmp = gmaps.geocode(place, language = "ko")
    
    # 구글맵 검색 될 경우
    if tmp:
        tmp_loc = tmp[0].get("geometry")
        tmp_lat = tmp_loc["location"]["lat"]
        tmp_lng = tmp_loc["location"]["lng"]
#         print(tmp_loc)
        
        #우리나라 위도 경도 값안에 들어있지 않는 경우
        if(tmp_lat > max_lat or tmp_lat < min_lat or tmp_lng > max_lng or tmp_lng < min_lng):
            place_lat.append("0")
            place_lng.append("0")
            
        #우리나라 위도 경도 값 안에 들어있는 경우
        else:
            place_lat.append(tmp_lat) # 위도 추가
            place_lng.append(tmp_lng) # 경도 추가
    # 검색 안 될 경우 0으로 입력
    else:
        place_lat.append("0")
        place_lng.append("0")
        
print("위경도 추가 완료")
 
# list -> dataframe, 열 이름 변경 
df_list2 = pd.DataFrame(place_lat)
df_list2 = df_list2.rename(columns = {0: "lat"})
df_list3 = pd.DataFrame(place_lng)
df_list3 = df_list3.rename(columns = {0: "lng"})
 
# dataframe 3개 합치기
df = pd.concat([df_list, df_list2, df_list3], axis = 1)
# 위경도 0인 행 삭제
df = df.query("lat != '0'")
 
df.to_csv(filename+"_location.csv", encoding = "utf-8-sig")
 
df.tail()
# Out:
# 위경도 추가 완료
#      Unnamed: 0         Name  Score  Review  \
# 525         525  명인등심 압구정직영점    4.3      62
# 526         526    샘밭막국수 서초점    3.2      35
# 527         527          옥탑방    4.4     375
# 528         528       고깃집왕고을    4.2     118
# 529         529          채화정    3.9      76
#
#                                        Link  \
# 525    https://place.map.kakao.com/21401237
# 526   https://place.map.kakao.com/130561410
# 527  https://place.map.kakao.com/1817798476
# 528  https://place.map.kakao.com/1294029566
# 529     https://place.map.kakao.com/8539855
#
#                                                   Addr        lat         lng
# 525               \n서울 강남구 도산대로 211\n(지번) 신사동 587-14\n  37.520568  127.029682
# 526  \n서울 서초구 서초중앙로24길 27 지파이브센트럴플라자 지하1층\n(지번) 서초동...  37.495414  127.016403
# 527             \n서울 은평구 서오릉로 115 1층\n(지번) 역촌동 2-136\n  37.609738  126.919239
# 528         \n서울 성동구 왕십리로24길 10-2 1층\n(지번) 도선동 152-1\n  37.563116  127.034119
# ...

# %%
#음식점 지도 만들기
import pandas as pd
import folium
import webbrowser
from folium.plugins import MarkerCluster
 
data_frame = pd.read_csv("everyweloc.csv",encoding='utf-8')
# data_frame = pd.DataFrame(results, columns=['name', 'address',"lat","long"])
data_frame
map = folium.Map(location = [35.8797296,128.4964884], zoom_start =7)
marker_cluster = MarkerCluster().add_to(map)
 
for index,a in data_frame.iterrows():
    
    #평점 4점 이상 빨강
    if float(a["Score"]) >=4:
        score_color = "red"
    
    #평점 3점이상 오렌지
    elif float(a["Score"]) >=3:
        score_color = "orange"
    
    #3점 미만
    else:
        score_color = "lightgreen"
    
    print_popup= str(a["Name"])+"<br> 평점 : "+ str(a["Score"])+" <br> 리뷰수 : "+str(a["Review"])+ "<br> 주소 : "+str(a["Addr"])+ "<br>"+'<a href="'+ str(a["Link"]) + '" target="_self">'+str(a["Link"])+'</a>' 
    
    folium.Marker(location = [a["lat"], a["lng"]],
    popup =print_popup, icon=folium.Icon(color=score_color)).add_to(marker_cluster)
 
map
map.save('selectWestern.html')
 
#웹에 띄워줌
webbrowser.open('selectWestern.html') 
print_popup
# Out:
# '옥탑방<br> 평점 : 4.4 <br> 리뷰수 : 375<br> 주소 : \n서울 은평구 서오릉로 115 1층\n(지번) 역촌동 2-136\n<br><a href="https://place.map.kakao.com/1817798476" target="_self">https://place.map.kakao.com/1817798476</a>'
